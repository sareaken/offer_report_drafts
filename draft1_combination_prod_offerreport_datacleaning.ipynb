# %% [markdown]
# DRAFT 1: Two Code Blocks

# %%
import pandas as pd
import numpy as np
import re
from google.colab import files
uploaded = files.upload()
import io

df2 = pd.read_csv(io.BytesIO(uploaded['raw_2023_OfferReport.csv']))

df2['Updated_On'] = pd.to_datetime(df2['Updated_On'])

df2.dropna(subset=['Offer Text'], inplace=True)

clean_data = df2.drop(columns=['Message ID','Offer Disclaimer', 'Unpublish Date','Archive Date','Offer Message', 'Campaign Order Id','Expiration Date', 'Recurring Expiration Days', 'Offer Type', 'Updated By', 'Item Version', "Target Audience Qualifier"])

clean_data = clean_data[clean_data['Updated_On']>'2022-12']

CLEANR = re.compile('<.*?>')
clean_data['Offer Text'] = clean_data['Offer Text'].str.replace(r'<[^<>]*>', '', regex=True)

def conditions(s):
    if (s['Client Name'] == "AutoNation Toyota Weston" or s['Client Name'] == "West Kendall Toyota" or s['Client Name'] == "Kendall Toyota" or s['Client Name'] == "Headquarter Toyota" or s['Client Name'] == "Toyota of North Miami" or s['Client Name'] == "Toyota of Deerfield Beach" or s['Client Name'] == "South Dade Toyota" or s['Client Name'] == "Al Hendrickson Toyota" or s['Client Name'] == "Ed Morse Delray Toyota" or s['Client Name'] == "Earl Stewart Toyota" or s['Client Name'] == "Toyota of Hollywood" or s['Client Name'] == "Doral Toyota" or s['Client Name'] == "Southern 441 Toyota" or s['Client Name'] == "Palm Beach Toyota" or s['Client Name'] == "Lipton Toyota"):
        return "District 1"
    elif (s['Client Name'] == "Sebring Toyota" or s['Client Name'] == "AutoNation Toyota Pinellas Park" or s['Client Name'] == "AutoNation Toyota Fort Myers" or s['Client Name'] == "Sun Toyota" or s['Client Name'] == "Courtesy Toyota of Brandon" or s['Client Name'] == "Wesley Chapel Toyota" or s['Client Name'] == "Stadium Toyota" or s['Client Name'] == "Gettel Toyota of Lakewood" or s['Client Name'] == "Gettel Toyota of Charlotte County" or s['Client Name'] == "Village Toyota" or s['Client Name'] == "Toyota of Tampa Bay" or s['Client Name'] == "Clearwater Toyota" or s['Client Name'] == "Germain Toyota of Naples" or s['Client Name'] == "Gettel Toyota of Bradenton" or s['Client Name'] == "Venice Toyota" or s['Client Name'] == "Sarasota Toyota" or s['Client Name'] == "Lakeland Toyota"):
        return "District 2"
    elif (s['Client Name'] == "Toyota of Vero Beach" or s['Client Name'] == "Daytona Toyota" or s['Client Name'] == "Central Florida Toyota" or s['Client Name'] == "Phillips Toyota" or s['Client Name'] == "Gatorland Toyota" or s['Client Name'] == "DeLuca Toyota" or s['Client Name'] == "Bev Smith Toyota" or s['Client Name'] == "Parks Toyota of DeLand" or s['Client Name'] == "Toyota of Orlando" or s['Client Name'] == "Mike Erdman Toyota" or s['Client Name'] == "Treasure Coast Toyota" or s['Client Name'] == "Toyota of Melbourne" or s['Client Name'] == "Toyota of Clermont" or  s['Client Name'] == "AutoNation Toyota Winter Park" or  s['Client Name'] == "Miracle Toyota" or  s['Client Name'] == "Seminole Toyota"):
        return "District 3"
    elif (s['Client Name'] == "Peter Boulware Toyota" or s['Client Name'] == "Ernie Palmer Toyota" or s['Client Name'] == "Arlington Toyota" or s['Client Name'] == "Beaver Toyota St Augustine" or s['Client Name'] == "Walker Jones Toyota" or s['Client Name'] == "Peter Boulware Toyota" or s['Client Name'] == "Hutchinson Toyota Of Albany" or s['Client Name'] == "Thomasville Toyota" or s['Client Name'] == "Keith Pierson Toyota" or s['Client Name'] == "Valdosta Toyota" or s['Client Name'] == "Rountree Moore Toyota" or s['Client Name'] == "I - 95 Toyota" or s['Client Name'] == "Coggin Toyota at the Avenues"):
        return "District 4"
    elif (s['Client Name'] == "Palmers Toyota Superstore" or s['Client Name'] == "McKinnon Toyota" or s['Client Name'] == "Eastern Shore Toyota" or s['Client Name'] == "Toyota of Fort Walton Beach" or s['Client Name'] == "Springhill Toyota" or s['Client Name'] == "Panama City Toyota" or s['Client Name'] == "Lynch Toyota of Auburn" or s['Client Name'] == "Toyota Of Dothan" or s['Client Name'] == "Reinhardt Toyota" or s['Client Name'] == "Bob Tyler Toyota" or s['Client Name'] == "Bondy's Enterprise Toyota" or s['Client Name'] == "Marianna Toyota"):
        return "District 5"
    elif (s['Client Name'] == "Greenway Toyota of the Shoals" or s['Client Name'] == "Hoover Toyota" or s['Client Name'] == "Tuscaloosa Toyota" or s['Client Name'] == "North Georgia Toyota" or s['Client Name'] == "Bill Penney Toyota of Jasper" or s['Client Name'] == "Sand Mountain Toyota" or s['Client Name'] == "Scott Crump Toyota" or s['Client Name'] == "Serra Toyota of Decatur" or s['Client Name'] == "High Country Toyota" or s['Client Name'] == "Bill Penney Toyota" or s['Client Name'] == "Toyota of Gadsden" or s['Client Name'] == "Riverside Toyota" or s['Client Name'] == "Limbaugh Toyota" or s['Client Name'] == "Serra Toyota - Birmingham" or s['Client Name'] == "Sunny King Toyota" or s['Client Name'] == "Toyota of Sylacauga"):
        return "District 6"
    elif (s['Client Name'] == "Five Star Toyota of Milledgeville" or s['Client Name'] == "Chatham Parkway Toyota" or s['Client Name'] == "Pitts Toyota" or s['Client Name'] == "Miracle Toyota of North Augusta" or s['Client Name'] == "Stokes Toyota Hilton Head" or s['Client Name'] == "Stokes Toyota Beaufort" or s['Client Name'] == "Butler Toyota of Macon" or s['Client Name'] == "LaGrange Toyota" or s['Client Name'] == "Heyward Allen Toyota" or s['Client Name'] == "Lowe Toyota Of Warner Robins" or s['Client Name'] == "Milton Ruben Toyota Of Augusta" or s['Client Name'] == "Bob Richards Toyota" or s['Client Name'] == "Savannah Toyota" or s['Client Name'] == "Franklin Toyota" or s['Client Name'] == "Rivertown Toyota"):
        return "District 7"
    elif (s['Client Name'] == "Nalley Toyota Union City" or s['Client Name'] == "AutoNation Toyota Thornton Road" or s['Client Name'] == "AutoNation Toyota Mall of Georgia" or s['Client Name'] == "Rick Hendrick Toyota Sandy Springs" or s['Client Name'] == "Marietta Toyota" or s['Client Name'] == "Milton Martin Toyota" or s['Client Name'] == "Atlanta Toyota" or s['Client Name'] == "Beaver Toyota of Cumming" or s['Client Name'] == "Toyota South Atlanta" or s['Client Name'] == "Toyota of Newnan" or s['Client Name'] == "Nalley Toyota Stonecrest" or s['Client Name'] == "Jim Ellis Toyota of McDonough" or s['Client Name'] == "Cherokee County Toyota" or s['Client Name'] == "Nalley Toyota of Roswell" or s['Client Name'] == "Cobb County Toyota" or s['Client Name'] == "Stone Mountain Toyota" or s['Client Name'] == "World Toyota"):
        return "District 8"
    elif (s['Client Name'] == "Peter Boulware Toyota of Columbia" or s['Client Name'] =="Ballentine Toyota" or s['Client Name'] == "Scott Will Toyota" or s['Client Name'] == "Fred Anderson Toyota of Charleston" or s['Client Name'] == "Lugoff Toyota" or s['Client Name'] == "Sparks Toyota" or s['Client Name'] == "Davis Toyota of Orangeburg" or s['Client Name'] == "Ralph Hayes Toyota of Anderson" or s['Client Name'] == "Davis Toyota of Orangeburg" or s['Client Name'] == "Spartanburg Toyota" or s['Client Name'] == "Toyota Of Easley" or s['Client Name'] == "Dave Edwards Toyota" or s['Client Name'] == "Florence Toyota" or s['Client Name'] == "Hendrick Toyota of North Charleston" or s['Client Name'] == "Toyota of Greer" or s['Client Name'] == "Jim Hudson Toyota" or s['Client Name'] == "Toyota of Greenville" or s['Client Name'] == "Midlands Toyota"):
        return "District 9"
    elif (s['Client Name'] == "Bryan Easler Toyota" or s['Client Name'] == "Cloninger Toyota" or s['Client Name'] == "Toyota of Gastonia" or s['Client Name'] == "Modern Toyota of Boone" or s['Client Name'] == "Scott Clark Toyota" or s['Client Name'] == "Mount Airy Toyota" or s['Client Name'] == "Toyota of North Charlotte" or s['Client Name'] == "Flow Toyota" or s['Client Name'] == "Mike Johnsons Hickory Toyota" or s['Client Name'] == "Classic Toyota of North Wilkesboro" or s['Client Name'] == "Town and Country Toyota" or s['Client Name'] == "Hendrick Toyota of Concord" or s['Client Name'] == "Fred Anderson Toyota of Asheville"):
        return "District 10"
    elif (s['Client Name'] == "Toyota of Greensboro" or s['Client Name'] == "Toyota of Goldsboro" or s['Client Name'] == "Griffin Toyota" or s['Client Name'] == "Modern Toyota of Asheboro" or s['Client Name'] == "Modern Toyota" or s['Client Name'] == "Fred Anderson Toyota of Sanford" or s['Client Name'] == "Vann York Toyota Inc" or s['Client Name'] == "Leith Toyota" or s['Client Name'] == "Hendrick Toyota Apex" or s['Client Name'] == "Rice Toyota" or s['Client Name'] == "Mark Jacobson Toyota" or s['Client Name'] == "Cox Toyota" or s['Client Name'] == "Classic Toyota of Henderson" or s['Client Name'] == "Fred Anderson Toyota of Raleigh" or s['Client Name'] == "Pinehurst Toyota"):
        return "District 11"
    elif (s['Client Name'] == "Toyota of Roanoke Rapids" or s['Client Name'] == "Hall Toyota Elizabeth City" or s['Client Name'] == "Hendrick Toyota of Wilmington" or s['Client Name'] == "Rick Hendrick Toyota" or s['Client Name'] == "Massey Toyota" or s['Client Name'] == "Peterson Toyota" or s['Client Name'] == "Stevenson-Hendrick Toyota" or s['Client Name'] == "Hubert Vester Toyota of Wilson" or s['Client Name'] == "Deacon Jones Toyota" or s['Client Name'] == "Greenville Toyota" or s['Client Name'] == "Rocky Mount Toyota" or s['Client Name'] == "Toyota of New Bern"):
        return "District 12"
    else:
        return "Unknown"

clean_data['Region'] = df2.apply(conditions, axis=1)

dealers_unknown = clean_data.query("Region=='Unknown'")["Client Name"]

clean_data = clean_data[~clean_data['Client Name'].str.contains('Toyota Test Dealer 1')]

def conditions2(s):
    if (s['Target Audience'] == "Lease End" or s['Target Audience'] == "Lease End 1" or s['Target Audience'] == "Lease End 1-3 Months" or s['Target Audience'] == "Lease End 4" or s['Target Audience'] == "Lease End 4-6 Months"  or s['Target Audience'] == "Lease End 7" or s['Target Audience'] == "Lease End 7-12 Months"):
        return "Sales: Lease End"
    elif (s['Target Audience'] == "Service: Tires Overdue - Direct Mail only" or s['Target Audience'] == "Service: Tires Overdue (Smart Mail only)" or s['Target Audience'] == "Tires Overdue Direct Mail" or s['Target Audience'] == "Tires Overdue DM"):
        return "Service: Tires Overdue - 6x11 Direct Mail"
    elif (s['Target Audience'] == "Service Engager Follow Up DM"):
        return "Service: Service Engager Follow Up - 4x6 Direct Mail"
    elif (s['Target Audience'] == "Tires Due DM"):
        return "Service: Tires Due - Direct Mail 4x6"
    elif (s['Target Audience'] == "TLE Inactive 13-23 Months DM"):
        return "Service: TLE Inactive (13-23 Months) - 6x11 Direct Mail"
    elif (s['Target Audience'] == "Business Opportunity 13 Months DM"):
        return "Service: Business Opportunity Maintain (13 Months) - Direct Mail 4x6"
    elif (s['Target Audience'] == "TLE At Risk 7-12 Months DM"):
        return "Service: TLE At Risk (7-12 Months) - 6x11 Direct Mail"
    elif (s['Target Audience'] == "Additional Services Recommended DM"):
        return "Service: Additional Services Recommended - 6x11 Direct Mail"
    elif (s['Target Audience'] == "Business Opportunity 7-12 Months DM"):
        return "Service: Business Opportunity Maintain (7-12 Months) - 6x11 Direct Mail"
    elif (s['Target Audience'] == "Service Overdue after ToyotaCare DM"):
        return "Service: Service Overdue after ToyotaCare 6x11Direct Mail"
    elif (s['Target Audience'] == "Service Due After Toyotacare DM"):
        return "Service: Service Due After ToyotaCare  - 4x6 Direct Mail"
    elif (s['Target Audience'] == "Accessories After 1 Year"):
        return "Service: Accessories After 1 Year"
    elif (s['Target Audience'] == "TLE At Risk 7-12 Months"):
        return "Service: TLE At Risk (7-12 Months)"
    elif (s['Target Audience'] == "TLE Inactive 13-23 Months"):
        return "Service: TLE Inactive (13-23 Months)"
    elif (s['Target Audience'] == "TLE Inactive 24 Plus Months"):
        return "Service: TLE Inactive (24+ Months)"
    elif (s['Target Audience'] == "TLE Inactive 24 Months DM"):
        return "Service: TLE Inactive (24+ Months) - 6x11 Direct Mail"
    elif (s['Target Audience'] == "Additional Services Recommended 3"):
        return "Service: Additional Services Recommended 3"
    elif (s['Target Audience'] == "Accessories After Purchase"):
        return "Service: Accessories After Purchase"
    elif (s['Target Audience'] == "Additional Services Recommended 1"):
        return "Service: Additional Services Recommended 1"
    elif (s['Target Audience'] == "Additional Services Recommended 2"):
        return "Service: Additional Services Recommended 2"
    elif (s['Target Audience'] == "Service Due After ToyotaCare"):
        return "Service: Service Due After Toyotacare"
    elif (s['Target Audience'] == "Toyoguard Overdue DM"):
        return "Service: Toyoguard Overdue 6x11Direct Mail"
    elif (s['Target Audience'] == "Toyoguard Due DM"):
        return "Service: Toyoguard Due 4x6 Direct Mail"
    elif (s['Target Audience'] == "Tires Overdue"):
        return "Service: Tires Overdue"
    elif (s['Target Audience'] == "Tires Due"):
        return "Service: Tires Due"
    elif (s['Target Audience'] == "Service Overdue After ToyotaCare"):
        return "Service: Service Overdue After ToyotaCare"
    elif (s['Target Audience'] == "Service Intro After Purchase"):
        return "Service: Service Intro After Purchase"
    elif (s['Target Audience'] == "Service Thank You"):
        return "Service: Service Thank You"
    elif (s['Target Audience'] == "Service Engagement Follow Up"):
        return "Service: Service Engager Follow-Up"
    elif (s['Target Audience'] == "Toyoguard Overdue"):
        return "Service: Toyoguard Overdue"
    elif (s['Target Audience'] == "ToyotaCare Due"):
        return "Service: ToyotaCare Due"
    elif (s['Target Audience'] == "Missed Appointment Reminder"):
        return "Service: Missed Appointment Reminder"
    elif (s['Target Audience'] == "ToyotaCare Non-Responder"):
        return "Service: ToyotaCare Non-Responder"
    elif (s['Target Audience'] == "Toyoguard Due"):
        return "Service: Toyoguard Due"
    elif (s['Target Audience'] == "Appointment Reminder"):
        return "Service: Appointment Reminder"
    elif (s['Target Audience'] == "Lease End Direct Mail"):
        return "Sales: Lease End - Direct Mail 4x6"
    elif (s['Target Audience'] == "High Mileage Upgrade Direct Mail"):
        return "Sales: High Mileage Upgrade - Direct Mail 4x6"
    else:
        return "Unknown"

clean_data['campaign_new'] = clean_data.apply(conditions2, axis=1)

campaign_unknown = clean_data.query("campaign_new=='Unknown'")["Target Audience"]

def conditions3(s):
    if (s['campaign_new'] == "Sales: High Mileage Upgrade - Direct Mail 4x6" or s['campaign_new'] == "Service: Additional Services Recommended - Direct Mail 4x6" or s['campaign_new'] == "Sales: Lease End - Direct Mail 4x6" or s['campaign_new'] == "Service: Toyoguard Due 4x6 Direct Mail" or s['campaign_new'] == "Service: Toyoguard Overdue 6x11Direct Mail" or s['campaign_new'] == "Service: Business Opportunity Maintain (7-12 Months) - Direct Mail 4x6" or s['campaign_new'] == "Service: TLE At Risk (7-12 Months) - Direct Mail 4x6" or s['campaign_new'] == "Sales Segment: Cars" or s['campaign_new'] == "Sales: Lease End" or s['campaign_new'] == "Sales: Lease End - 6x11 Direct Mail" or s['campaign_new'] == "Sales: Loan Payoff" or s['campaign_new'] == "Sales: Loan Payoff - 6x11 Direct Mail" or s['campaign_new'] == "Service: Accessories After 1 Year" or s['campaign_new'] == "Service: Accessories After Purchase" or s['campaign_new'] == "Service: Additional Services Recommended - 6x11 Direct Mail" or s['campaign_new'] == "Service: Additional Services Recommended 1" or s['campaign_new'] == "Service: Appointment Reminder" or s['campaign_new'] == "Service: Business Opportunity Maintain (7-12 Months)" or s['campaign_new'] == "Service: Missed Appointment Reminder" or s['campaign_new'] == "Service: Service Due After Toyotacare" or s['campaign_new'] == "Service: Service Due After ToyotaCare  - 4x6 Direct Mail" or s['campaign_new'] == "Service: Service Engager Follow Up" or s['campaign_new'] == "Service: Service Engager Follow Up - 4x6 Direct Mail" or s['campaign_new'] == "Service: Service Intro After Purchase" or s['campaign_new'] == "Service: Service Reminder" or s['campaign_new'] == "Service: Service Thank You" or s['campaign_new'] == "Service: Tires Due" or s['campaign_new'] == "Service: Tires Due - Direct Mail 4x6" or s['campaign_new'] == "Service: Tires Overdue" or s['campaign_new'] == "" or s['campaign_new'] == "Service: TLE At Risk (7-12 Months)" or s['campaign_new'] == "Service: TLE At Risk (7-12 Months) - 6x11 Direct Mail" or s['campaign_new'] == "Service: Toyoguard Due" or s['campaign_new'] == "Service: Toyoguard Overdue" or s['campaign_new'] == "Service: ToyotaCare Due" or s['campaign_new'] == "Service: Tires Overdue - 6x11 Direct Mail" or s['campaign_new'] == "Service: Service Due After ToyotaCare" or s['campaign_new'] == "Service: Service Due After ToyotaCare 6x11 Direct Mail" or s['campaign_new'] == "General Service" or s['campaign_new'] == "New Servicers" or s['campaign_new'] == "General Sales" or s['campaign_new'] == "Lapsed Servicers" or s['campaign_new'] == "Regular Servicers"):
        return "Active"
    elif (s['campaign_new'] == "Service: TLE Inactive (24+ Months) - 6x11 Direct Mail" or "Service: Business Opportunity Maintain (13 Months) - Direct Mail 4x6" or s['campaign_new'] == "Service: Service Due After ToyotaCare  - 4x6 Direct Mail " or s['campaign_new'] == "Service: Service Overdue after ToyotaCare 6x11Direct Mail" or s['campaign_new'] == "Service: TLE Inactive (13-23 Months) - Direct Mail 4x6" or s['campaign_new'] == "Service: Additional Services Recommended 2" or s['campaign_new'] == "Service: Additional Services Recommended 3" or s['campaign_new'] == "Service: Business Opportunity Improve (12+ Months)" or s['campaign_new'] == "Service: Service Overdue After ToyotaCare" or s['campaign_new'] == "Service: TLE Inactive (13-23 Months)" or  s['campaign_new'] == "Service: TLE Inactive (13-23 Months) - 6x11 Direct Mail" or  s['campaign_new'] == "Service: TLE Inactive (24+ Months)" or  s['campaign_new'] == "Service: ToyotaCare Non-Responder"):
        return "Inactive"
    else:
        return "Unknown"

clean_data['active_inactive'] = clean_data.apply(conditions3, axis=1)

null_active_inctive = clean_data[clean_data['active_inactive'].isnull()]
unique_names = null_active_inctive['Offer Text']
number_of_rows_AI = unique_names.shape[0]

clean_data.loc[clean_data['Offer Text'].str.contains('Battery'), 'Offer_Group'] = 'Key Products - Battery'

clean_data.loc[clean_data['Offer Text'].str.contains('oil'), 'Offer_Group'] = 'Key Products - Oil'
clean_data.loc[clean_data['Offer Text'].str.contains('Oil'), 'Offer_Group'] = 'Key Products - Oil'
clean_data.loc[clean_data['Offer Text'].str.contains('OIL'), 'Offer_Group'] = 'Key Products - Oil'
clean_data.loc[clean_data['Offer Text'].str.contains('OIL AND FILTER'), 'Offer_Group'] = 'Key Products - Oil'

clean_data.loc[clean_data['Offer Text'].str.contains('Sunbit'), 'Offer_Group'] = 'Sunbit Special'

clean_data.loc[clean_data['Offer Text'].str.contains('accessory'), 'Offer_Group'] = 'Accessories Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('Accessories'), 'Offer_Group'] = 'Accessories Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('ACCESSORIES'), 'Offer_Group'] = 'Accessories Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('accessories'), 'Offer_Group'] = 'Accessories Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('Accessory'), 'Offer_Group'] = 'Accessories Discount'


clean_data.loc[clean_data['Offer Text'].str.contains('Buy 3 tires, get the 4th for $1.00!'), 'Offer_Group'] = 'B3G1 Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('Buy 3 Tires'), 'Offer_Group'] = 'B3G1 Tires'

clean_data.loc[clean_data['Offer Text'].str.contains('with purchase and installation of brake pads'), 'Offer_Group'] = 'Brake Event Special Special'

clean_data.loc[clean_data['Offer Text'].str.contains('air filter'), 'Offer_Group'] = 'Key Products - Filters'
clean_data.loc[clean_data['Offer Text'].str.contains('Cabin Filter'), 'Offer_Group'] = 'Key Products - Filters'
clean_data.loc[clean_data['Offer Text'].str.contains('Air Filter'), 'Offer_Group'] = 'Key Products - Filters'
clean_data.loc[clean_data['Offer Text'].str.contains('Engine Filter'), 'Offer_Group'] = 'Key Products - Filters'
clean_data.loc[clean_data['Offer Text'].str.contains('Engine filter'), 'Offer_Group'] = 'Key Products - Filters'
clean_data.loc[clean_data['Offer Text'].str.contains('CABIN AIR FILTER'), 'Offer_Group'] = 'Key Products - Filters'

clean_data.loc[clean_data['Offer Text'].str.contains('brake'), 'Offer_Group'] = 'Key Products - Brakes'
clean_data.loc[clean_data['Offer Text'].str.contains('brakes'), 'Offer_Group'] = 'Key Products - Brakes'

clean_data.loc[clean_data['Offer Text'].str.contains('wiper'), 'Offer_Group'] = 'Key Products - Wipers'
clean_data.loc[clean_data['Offer Text'].str.contains('wipers'), 'Offer_Group'] = 'Key Products - Wipers'
clean_data.loc[clean_data['Offer Text'].str.contains('Wipers'), 'Offer_Group'] = 'Key Products - Wipers'
clean_data.loc[clean_data['Offer Text'].str.contains('WIPER'), 'Offer_Group'] = 'Key Products - Wipers'
clean_data.loc[clean_data['Offer Text'].str.contains('Wiper'), 'Offer_Group'] = 'Key Products - Wipers'

clean_data.loc[clean_data['Offer Text'].str.contains('service'), 'Offer_Group'] = 'Service Appointment Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('Service'), 'Offer_Group'] = 'Service Appointment Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('SERVICE'), 'Offer_Group'] = 'Service Appointment Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('Services'), 'Offer_Group'] = 'Service Appointment Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('SPEND AND SAVE'), 'Offer_Group'] = 'Service Appointment Discount - Spend and Save'
clean_data.loc[clean_data['Offer Text'].str.contains('Maintenance'), 'Offer_Group'] = 'Service Appointment Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('maintenance'), 'Offer_Group'] = 'Service Appointment Discount'

clean_data.loc[clean_data['Offer Text'].str.contains('SUNBIT!'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('Alignment'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('tire'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('tires'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('TIRE'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('Tire'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('Stay Safe Now!'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('STAY SAFE NOW'), 'Offer_Group'] = 'Key Products - Tires'

clean_data.loc[clean_data['Offer Text'].str.contains('Spend More, Save More'), 'Offer_Group'] = 'Spend More, Save More Special'

# Replace null values in a specific column, e.g., 'Column_Name'
clean_data['Offer_Group'].fillna("Other", inplace=True)


null_rows = clean_data[clean_data['Offer_Group'].isnull()]
unique_names = null_rows['Offer Text']
number_of_rows = unique_names.shape[0]

# !pip install xlsxwriter

writer = pd.ExcelWriter('final_clean_data_jan_mar23.xlsx', engine='xlsxwriter', options={'strings_to_urls': False})
clean_data.to_excel(writer, index=False, sheet_name='Sheet1', encoding='utf-8')
writer.save()

from google.colab import files
files.download('final_clean_data_jan_mar23.xlsx')
# Out:
#      <input type="file" id="files-7ca7923a-8444-4219-a3d0-dcd9176cb98f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ca7923a-8444-4219-a3d0-dcd9176cb98f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2 = pd.read_csv(io.BytesIO(uploaded['raw_2023_OfferReport.csv']))

df2['Updated_On'] = pd.to_datetime(df2['Updated_On'])

df2.dropna(subset=['Offer Text'], inplace=True)

clean_data = df2.drop(columns=['Message ID','Offer Disclaimer', 'Unpublish Date','Archive Date','Offer Message', 'Campaign Order Id','Expiration Date', 'Recurring Expiration Days', 'Offer Type', 'Updated By', 'Item Version', "Target Audience Qualifier"])

clean_data = clean_data[clean_data['Updated_On']>'2022-12']

CLEANR = re.compile('<.*?>')
clean_data['Offer Text'] = clean_data['Offer Text'].str.replace(r'<[^<>]*>', '', regex=True)

def conditions(s):
    if (s['Client Name'] == "AutoNation Toyota Weston" or s['Client Name'] == "West Kendall Toyota" or s['Client Name'] == "Kendall Toyota" or s['Client Name'] == "Headquarter Toyota" or s['Client Name'] == "Toyota of North Miami" or s['Client Name'] == "Toyota of Deerfield Beach" or s['Client Name'] == "South Dade Toyota" or s['Client Name'] == "Al Hendrickson Toyota" or s['Client Name'] == "Ed Morse Delray Toyota" or s['Client Name'] == "Earl Stewart Toyota" or s['Client Name'] == "Toyota of Hollywood" or s['Client Name'] == "Doral Toyota" or s['Client Name'] == "Southern 441 Toyota" or s['Client Name'] == "Palm Beach Toyota" or s['Client Name'] == "Lipton Toyota"):
        return "District 1"
    elif (s['Client Name'] == "Sebring Toyota" or s['Client Name'] == "AutoNation Toyota Pinellas Park" or s['Client Name'] == "AutoNation Toyota Fort Myers" or s['Client Name'] == "Sun Toyota" or s['Client Name'] == "Courtesy Toyota of Brandon" or s['Client Name'] == "Wesley Chapel Toyota" or s['Client Name'] == "Stadium Toyota" or s['Client Name'] == "Gettel Toyota of Lakewood" or s['Client Name'] == "Gettel Toyota of Charlotte County" or s['Client Name'] == "Village Toyota" or s['Client Name'] == "Toyota of Tampa Bay" or s['Client Name'] == "Clearwater Toyota" or s['Client Name'] == "Germain Toyota of Naples" or s['Client Name'] == "Gettel Toyota of Bradenton" or s['Client Name'] == "Venice Toyota" or s['Client Name'] == "Sarasota Toyota" or s['Client Name'] == "Lakeland Toyota"):
        return "District 2"
    elif (s['Client Name'] == "Toyota of Vero Beach" or s['Client Name'] == "Daytona Toyota" or s['Client Name'] == "Central Florida Toyota" or s['Client Name'] == "Phillips Toyota" or s['Client Name'] == "Gatorland Toyota" or s['Client Name'] == "DeLuca Toyota" or s['Client Name'] == "Bev Smith Toyota" or s['Client Name'] == "Parks Toyota of DeLand" or s['Client Name'] == "Toyota of Orlando" or s['Client Name'] == "Mike Erdman Toyota" or s['Client Name'] == "Treasure Coast Toyota" or s['Client Name'] == "Toyota of Melbourne" or s['Client Name'] == "Toyota of Clermont" or  s['Client Name'] == "AutoNation Toyota Winter Park" or  s['Client Name'] == "Miracle Toyota" or  s['Client Name'] == "Seminole Toyota"):
        return "District 3"
    elif (s['Client Name'] == "Peter Boulware Toyota" or s['Client Name'] == "Ernie Palmer Toyota" or s['Client Name'] == "Arlington Toyota" or s['Client Name'] == "Beaver Toyota St Augustine" or s['Client Name'] == "Walker Jones Toyota" or s['Client Name'] == "Peter Boulware Toyota" or s['Client Name'] == "Hutchinson Toyota Of Albany" or s['Client Name'] == "Thomasville Toyota" or s['Client Name'] == "Keith Pierson Toyota" or s['Client Name'] == "Valdosta Toyota" or s['Client Name'] == "Rountree Moore Toyota" or s['Client Name'] == "I - 95 Toyota" or s['Client Name'] == "Coggin Toyota at the Avenues"):
        return "District 4"
    elif (s['Client Name'] == "Palmers Toyota Superstore" or s['Client Name'] == "McKinnon Toyota" or s['Client Name'] == "Eastern Shore Toyota" or s['Client Name'] == "Toyota of Fort Walton Beach" or s['Client Name'] == "Springhill Toyota" or s['Client Name'] == "Panama City Toyota" or s['Client Name'] == "Lynch Toyota of Auburn" or s['Client Name'] == "Toyota Of Dothan" or s['Client Name'] == "Reinhardt Toyota" or s['Client Name'] == "Bob Tyler Toyota" or s['Client Name'] == "Bondy's Enterprise Toyota" or s['Client Name'] == "Marianna Toyota"):
        return "District 5"
    elif (s['Client Name'] == "Greenway Toyota of the Shoals" or s['Client Name'] == "Hoover Toyota" or s['Client Name'] == "Tuscaloosa Toyota" or s['Client Name'] == "North Georgia Toyota" or s['Client Name'] == "Bill Penney Toyota of Jasper" or s['Client Name'] == "Sand Mountain Toyota" or s['Client Name'] == "Scott Crump Toyota" or s['Client Name'] == "Serra Toyota of Decatur" or s['Client Name'] == "High Country Toyota" or s['Client Name'] == "Bill Penney Toyota" or s['Client Name'] == "Toyota of Gadsden" or s['Client Name'] == "Riverside Toyota" or s['Client Name'] == "Limbaugh Toyota" or s['Client Name'] == "Serra Toyota - Birmingham" or s['Client Name'] == "Sunny King Toyota" or s['Client Name'] == "Toyota of Sylacauga"):
        return "District 6"
    elif (s['Client Name'] == "Five Star Toyota of Milledgeville" or s['Client Name'] == "Chatham Parkway Toyota" or s['Client Name'] == "Pitts Toyota" or s['Client Name'] == "Miracle Toyota of North Augusta" or s['Client Name'] == "Stokes Toyota Hilton Head" or s['Client Name'] == "Stokes Toyota Beaufort" or s['Client Name'] == "Butler Toyota of Macon" or s['Client Name'] == "LaGrange Toyota" or s['Client Name'] == "Heyward Allen Toyota" or s['Client Name'] == "Lowe Toyota Of Warner Robins" or s['Client Name'] == "Milton Ruben Toyota Of Augusta" or s['Client Name'] == "Bob Richards Toyota" or s['Client Name'] == "Savannah Toyota" or s['Client Name'] == "Franklin Toyota" or s['Client Name'] == "Rivertown Toyota"):
        return "District 7"
    elif (s['Client Name'] == "Nalley Toyota Union City" or s['Client Name'] == "AutoNation Toyota Thornton Road" or s['Client Name'] == "AutoNation Toyota Mall of Georgia" or s['Client Name'] == "Rick Hendrick Toyota Sandy Springs" or s['Client Name'] == "Marietta Toyota" or s['Client Name'] == "Milton Martin Toyota" or s['Client Name'] == "Atlanta Toyota" or s['Client Name'] == "Beaver Toyota of Cumming" or s['Client Name'] == "Toyota South Atlanta" or s['Client Name'] == "Toyota of Newnan" or s['Client Name'] == "Nalley Toyota Stonecrest" or s['Client Name'] == "Jim Ellis Toyota of McDonough" or s['Client Name'] == "Cherokee County Toyota" or s['Client Name'] == "Nalley Toyota of Roswell" or s['Client Name'] == "Cobb County Toyota" or s['Client Name'] == "Stone Mountain Toyota" or s['Client Name'] == "World Toyota"):
        return "District 8"
    elif (s['Client Name'] == "Peter Boulware Toyota of Columbia" or s['Client Name'] =="Ballentine Toyota" or s['Client Name'] == "Scott Will Toyota" or s['Client Name'] == "Fred Anderson Toyota of Charleston" or s['Client Name'] == "Lugoff Toyota" or s['Client Name'] == "Sparks Toyota" or s['Client Name'] == "Davis Toyota of Orangeburg" or s['Client Name'] == "Ralph Hayes Toyota of Anderson" or s['Client Name'] == "Davis Toyota of Orangeburg" or s['Client Name'] == "Spartanburg Toyota" or s['Client Name'] == "Toyota Of Easley" or s['Client Name'] == "Dave Edwards Toyota" or s['Client Name'] == "Florence Toyota" or s['Client Name'] == "Hendrick Toyota of North Charleston" or s['Client Name'] == "Toyota of Greer" or s['Client Name'] == "Jim Hudson Toyota" or s['Client Name'] == "Toyota of Greenville" or s['Client Name'] == "Midlands Toyota"):
        return "District 9"
    elif (s['Client Name'] == "Bryan Easler Toyota" or s['Client Name'] == "Cloninger Toyota" or s['Client Name'] == "Toyota of Gastonia" or s['Client Name'] == "Modern Toyota of Boone" or s['Client Name'] == "Scott Clark Toyota" or s['Client Name'] == "Mount Airy Toyota" or s['Client Name'] == "Toyota of North Charlotte" or s['Client Name'] == "Flow Toyota" or s['Client Name'] == "Mike Johnsons Hickory Toyota" or s['Client Name'] == "Classic Toyota of North Wilkesboro" or s['Client Name'] == "Town and Country Toyota" or s['Client Name'] == "Hendrick Toyota of Concord" or s['Client Name'] == "Fred Anderson Toyota of Asheville"):
        return "District 10"
    elif (s['Client Name'] == "Toyota of Greensboro" or s['Client Name'] == "Toyota of Goldsboro" or s['Client Name'] == "Griffin Toyota" or s['Client Name'] == "Modern Toyota of Asheboro" or s['Client Name'] == "Modern Toyota" or s['Client Name'] == "Fred Anderson Toyota of Sanford" or s['Client Name'] == "Vann York Toyota Inc" or s['Client Name'] == "Leith Toyota" or s['Client Name'] == "Hendrick Toyota Apex" or s['Client Name'] == "Rice Toyota" or s['Client Name'] == "Mark Jacobson Toyota" or s['Client Name'] == "Cox Toyota" or s['Client Name'] == "Classic Toyota of Henderson" or s['Client Name'] == "Fred Anderson Toyota of Raleigh" or s['Client Name'] == "Pinehurst Toyota"):
        return "District 11"
    elif (s['Client Name'] == "Toyota of Roanoke Rapids" or s['Client Name'] == "Hall Toyota Elizabeth City" or s['Client Name'] == "Hendrick Toyota of Wilmington" or s['Client Name'] == "Rick Hendrick Toyota" or s['Client Name'] == "Massey Toyota" or s['Client Name'] == "Peterson Toyota" or s['Client Name'] == "Stevenson-Hendrick Toyota" or s['Client Name'] == "Hubert Vester Toyota of Wilson" or s['Client Name'] == "Deacon Jones Toyota" or s['Client Name'] == "Greenville Toyota" or s['Client Name'] == "Rocky Mount Toyota" or s['Client Name'] == "Toyota of New Bern"):
        return "District 12"
    else:
        return "Unknown"

clean_data['Region'] = df2.apply(conditions, axis=1)

dealers_unknown = clean_data.query("Region=='Unknown'")["Client Name"]

clean_data = clean_data[~clean_data['Client Name'].str.contains('Toyota Test Dealer 1')]

def conditions2(s):
    if (s['Target Audience'] == "Lease End" or s['Target Audience'] == "Lease End 1" or s['Target Audience'] == "Lease End 1-3 Months" or s['Target Audience'] == "Lease End 4" or s['Target Audience'] == "Lease End 4-6 Months"  or s['Target Audience'] == "Lease End 7" or s['Target Audience'] == "Lease End 7-12 Months"):
        return "Sales: Lease End"
    elif (s['Target Audience'] == "Service: Tires Overdue - Direct Mail only" or s['Target Audience'] == "Service: Tires Overdue (Smart Mail only)" or s['Target Audience'] == "Tires Overdue Direct Mail" or s['Target Audience'] == "Tires Overdue DM"):
        return "Service: Tires Overdue - 6x11 Direct Mail"
    elif (s['Target Audience'] == "Service Engager Follow Up DM"):
        return "Service: Service Engager Follow Up - 4x6 Direct Mail"
    elif (s['Target Audience'] == "Tires Due DM"):
        return "Service: Tires Due - Direct Mail 4x6"
    elif (s['Target Audience'] == "TLE Inactive 13-23 Months DM"):
        return "Service: TLE Inactive (13-23 Months) - 6x11 Direct Mail"
    elif (s['Target Audience'] == "Business Opportunity 13 Months DM"):
        return "Service: Business Opportunity Maintain (13 Months) - Direct Mail 4x6"
    elif (s['Target Audience'] == "TLE At Risk 7-12 Months DM"):
        return "Service: TLE At Risk (7-12 Months) - 6x11 Direct Mail"
    elif (s['Target Audience'] == "Additional Services Recommended DM"):
        return "Service: Additional Services Recommended - 6x11 Direct Mail"
    elif (s['Target Audience'] == "Business Opportunity 7-12 Months DM"):
        return "Service: Business Opportunity Maintain (7-12 Months) - 6x11 Direct Mail"
    elif (s['Target Audience'] == "Service Overdue after ToyotaCare DM"):
        return "Service: Service Overdue after ToyotaCare 6x11Direct Mail"
    elif (s['Target Audience'] == "Service Due After Toyotacare DM"):
        return "Service: Service Due After ToyotaCare  - 4x6 Direct Mail"
    elif (s['Target Audience'] == "Accessories After 1 Year"):
        return "Service: Accessories After 1 Year"
    elif (s['Target Audience'] == "TLE At Risk 7-12 Months"):
        return "Service: TLE At Risk (7-12 Months)"
    elif (s['Target Audience'] == "TLE Inactive 13-23 Months"):
        return "Service: TLE Inactive (13-23 Months)"
    elif (s['Target Audience'] == "TLE Inactive 24 Plus Months"):
        return "Service: TLE Inactive (24+ Months)"
    elif (s['Target Audience'] == "TLE Inactive 24 Months DM"):
        return "Service: TLE Inactive (24+ Months) - 6x11 Direct Mail"
    elif (s['Target Audience'] == "Additional Services Recommended 3"):
        return "Service: Additional Services Recommended 3"
    elif (s['Target Audience'] == "Accessories After Purchase"):
        return "Service: Accessories After Purchase"
    elif (s['Target Audience'] == "Additional Services Recommended 1"):
        return "Service: Additional Services Recommended 1"
    elif (s['Target Audience'] == "Additional Services Recommended 2"):
        return "Service: Additional Services Recommended 2"
    elif (s['Target Audience'] == "Service Due After ToyotaCare"):
        return "Service: Service Due After Toyotacare"
    elif (s['Target Audience'] == "Toyoguard Overdue DM"):
        return "Service: Toyoguard Overdue 6x11Direct Mail"
    elif (s['Target Audience'] == "Toyoguard Due DM"):
        return "Service: Toyoguard Due 4x6 Direct Mail"
    elif (s['Target Audience'] == "Tires Overdue"):
        return "Service: Tires Overdue"
    elif (s['Target Audience'] == "Tires Due"):
        return "Service: Tires Due"
    elif (s['Target Audience'] == "Service Overdue After ToyotaCare"):
        return "Service: Service Overdue After ToyotaCare"
    elif (s['Target Audience'] == "Service Intro After Purchase"):
        return "Service: Service Intro After Purchase"
    elif (s['Target Audience'] == "Service Thank You"):
        return "Service: Service Thank You"
    elif (s['Target Audience'] == "Service Engagement Follow Up"):
        return "Service: Service Engager Follow-Up"
    elif (s['Target Audience'] == "Toyoguard Overdue"):
        return "Service: Toyoguard Overdue"
    elif (s['Target Audience'] == "ToyotaCare Due"):
        return "Service: ToyotaCare Due"
    elif (s['Target Audience'] == "Missed Appointment Reminder"):
        return "Service: Missed Appointment Reminder"
    elif (s['Target Audience'] == "ToyotaCare Non-Responder"):
        return "Service: ToyotaCare Non-Responder"
    elif (s['Target Audience'] == "Toyoguard Due"):
        return "Service: Toyoguard Due"
    elif (s['Target Audience'] == "Appointment Reminder"):
        return "Service: Appointment Reminder"
    elif (s['Target Audience'] == "Lease End Direct Mail"):
        return "Sales: Lease End - Direct Mail 4x6"
    elif (s['Target Audience'] == "High Mileage Upgrade Direct Mail"):
        return "Sales: High Mileage Upgrade - Direct Mail 4x6"
    else:
        return "Unknown"

clean_data['campaign_new'] = clean_data.apply(conditions2, axis=1)

campaign_unknown = clean_data.query("campaign_new=='Unknown'")["Target Audience"]

def conditions3(s):
    if (s['campaign_new'] == "Sales: High Mileage Upgrade - Direct Mail 4x6" or s['campaign_new'] == "Service: Additional Services Recommended - Direct Mail 4x6" or s['campaign_new'] == "Sales: Lease End - Direct Mail 4x6" or s['campaign_new'] == "Service: Toyoguard Due 4x6 Direct Mail" or s['campaign_new'] == "Service: Toyoguard Overdue 6x11Direct Mail" or s['campaign_new'] == "Service: Business Opportunity Maintain (7-12 Months) - Direct Mail 4x6" or s['campaign_new'] == "Service: TLE At Risk (7-12 Months) - Direct Mail 4x6" or s['campaign_new'] == "Sales Segment: Cars" or s['campaign_new'] == "Sales: Lease End" or s['campaign_new'] == "Sales: Lease End - 6x11 Direct Mail" or s['campaign_new'] == "Sales: Loan Payoff" or s['campaign_new'] == "Sales: Loan Payoff - 6x11 Direct Mail" or s['campaign_new'] == "Service: Accessories After 1 Year" or s['campaign_new'] == "Service: Accessories After Purchase" or s['campaign_new'] == "Service: Additional Services Recommended - 6x11 Direct Mail" or s['campaign_new'] == "Service: Additional Services Recommended 1" or s['campaign_new'] == "Service: Appointment Reminder" or s['campaign_new'] == "Service: Business Opportunity Maintain (7-12 Months)" or s['campaign_new'] == "Service: Missed Appointment Reminder" or s['campaign_new'] == "Service: Service Due After Toyotacare" or s['campaign_new'] == "Service: Service Due After ToyotaCare  - 4x6 Direct Mail" or s['campaign_new'] == "Service: Service Engager Follow Up" or s['campaign_new'] == "Service: Service Engager Follow Up - 4x6 Direct Mail" or s['campaign_new'] == "Service: Service Intro After Purchase" or s['campaign_new'] == "Service: Service Reminder" or s['campaign_new'] == "Service: Service Thank You" or s['campaign_new'] == "Service: Tires Due" or s['campaign_new'] == "Service: Tires Due - Direct Mail 4x6" or s['campaign_new'] == "Service: Tires Overdue" or s['campaign_new'] == "" or s['campaign_new'] == "Service: TLE At Risk (7-12 Months)" or s['campaign_new'] == "Service: TLE At Risk (7-12 Months) - 6x11 Direct Mail" or s['campaign_new'] == "Service: Toyoguard Due" or s['campaign_new'] == "Service: Toyoguard Overdue" or s['campaign_new'] == "Service: ToyotaCare Due" or s['campaign_new'] == "Service: Tires Overdue - 6x11 Direct Mail" or s['campaign_new'] == "Service: Service Due After ToyotaCare" or s['campaign_new'] == "Service: Service Due After ToyotaCare 6x11 Direct Mail" or s['campaign_new'] == "General Service" or s['campaign_new'] == "New Servicers" or s['campaign_new'] == "General Sales" or s['campaign_new'] == "Lapsed Servicers" or s['campaign_new'] == "Regular Servicers"):
        return "Active"
    elif (s['campaign_new'] == "Service: TLE Inactive (24+ Months) - 6x11 Direct Mail" or "Service: Business Opportunity Maintain (13 Months) - Direct Mail 4x6" or s['campaign_new'] == "Service: Service Due After ToyotaCare  - 4x6 Direct Mail " or s['campaign_new'] == "Service: Service Overdue after ToyotaCare 6x11Direct Mail" or s['campaign_new'] == "Service: TLE Inactive (13-23 Months) - Direct Mail 4x6" or s['campaign_new'] == "Service: Additional Services Recommended 2" or s['campaign_new'] == "Service: Additional Services Recommended 3" or s['campaign_new'] == "Service: Business Opportunity Improve (12+ Months)" or s['campaign_new'] == "Service: Service Overdue After ToyotaCare" or s['campaign_new'] == "Service: TLE Inactive (13-23 Months)" or  s['campaign_new'] == "Service: TLE Inactive (13-23 Months) - 6x11 Direct Mail" or  s['campaign_new'] == "Service: TLE Inactive (24+ Months)" or  s['campaign_new'] == "Service: ToyotaCare Non-Responder"):
        return "Inactive"
    else:
        return "Unknown"

clean_data['active_inactive'] = clean_data.apply(conditions3, axis=1)

null_active_inctive = clean_data[clean_data['active_inactive'].isnull()]
unique_names = null_active_inctive['Offer Text']
number_of_rows_AI = unique_names.shape[0]

clean_data.loc[clean_data['Offer Text'].str.contains('Battery'), 'Offer_Group'] = 'Key Products - Battery'

clean_data.loc[clean_data['Offer Text'].str.contains('oil'), 'Offer_Group'] = 'Key Products - Oil'
clean_data.loc[clean_data['Offer Text'].str.contains('Oil'), 'Offer_Group'] = 'Key Products - Oil'
clean_data.loc[clean_data['Offer Text'].str.contains('OIL'), 'Offer_Group'] = 'Key Products - Oil'
clean_data.loc[clean_data['Offer Text'].str.contains('OIL AND FILTER'), 'Offer_Group'] = 'Key Products - Oil'

clean_data.loc[clean_data['Offer Text'].str.contains('Sunbit'), 'Offer_Group'] = 'Sunbit Special'

clean_data.loc[clean_data['Offer Text'].str.contains('accessory'), 'Offer_Group'] = 'Accessories Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('Accessories'), 'Offer_Group'] = 'Accessories Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('ACCESSORIES'), 'Offer_Group'] = 'Accessories Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('accessories'), 'Offer_Group'] = 'Accessories Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('Accessory'), 'Offer_Group'] = 'Accessories Discount'


clean_data.loc[clean_data['Offer Text'].str.contains('Buy 3 tires, get the 4th for $1.00!'), 'Offer_Group'] = 'B3G1 Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('Buy 3 Tires'), 'Offer_Group'] = 'B3G1 Tires'

clean_data.loc[clean_data['Offer Text'].str.contains('with purchase and installation of brake pads'), 'Offer_Group'] = 'Brake Event Special Special'

clean_data.loc[clean_data['Offer Text'].str.contains('air filter'), 'Offer_Group'] = 'Key Products - Filters'
clean_data.loc[clean_data['Offer Text'].str.contains('Cabin Filter'), 'Offer_Group'] = 'Key Products - Filters'
clean_data.loc[clean_data['Offer Text'].str.contains('Air Filter'), 'Offer_Group'] = 'Key Products - Filters'
clean_data.loc[clean_data['Offer Text'].str.contains('Engine Filter'), 'Offer_Group'] = 'Key Products - Filters'
clean_data.loc[clean_data['Offer Text'].str.contains('Engine filter'), 'Offer_Group'] = 'Key Products - Filters'
clean_data.loc[clean_data['Offer Text'].str.contains('CABIN AIR FILTER'), 'Offer_Group'] = 'Key Products - Filters'

clean_data.loc[clean_data['Offer Text'].str.contains('brake'), 'Offer_Group'] = 'Key Products - Brakes'
clean_data.loc[clean_data['Offer Text'].str.contains('brakes'), 'Offer_Group'] = 'Key Products - Brakes'

clean_data.loc[clean_data['Offer Text'].str.contains('wiper'), 'Offer_Group'] = 'Key Products - Wipers'
clean_data.loc[clean_data['Offer Text'].str.contains('wipers'), 'Offer_Group'] = 'Key Products - Wipers'
clean_data.loc[clean_data['Offer Text'].str.contains('Wipers'), 'Offer_Group'] = 'Key Products - Wipers'
clean_data.loc[clean_data['Offer Text'].str.contains('WIPER'), 'Offer_Group'] = 'Key Products - Wipers'
clean_data.loc[clean_data['Offer Text'].str.contains('Wiper'), 'Offer_Group'] = 'Key Products - Wipers'

clean_data.loc[clean_data['Offer Text'].str.contains('service'), 'Offer_Group'] = 'Service Appointment Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('Service'), 'Offer_Group'] = 'Service Appointment Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('SERVICE'), 'Offer_Group'] = 'Service Appointment Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('Services'), 'Offer_Group'] = 'Service Appointment Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('SPEND AND SAVE'), 'Offer_Group'] = 'Service Appointment Discount - Spend and Save'
clean_data.loc[clean_data['Offer Text'].str.contains('Maintenance'), 'Offer_Group'] = 'Service Appointment Discount'
clean_data.loc[clean_data['Offer Text'].str.contains('maintenance'), 'Offer_Group'] = 'Service Appointment Discount'

clean_data.loc[clean_data['Offer Text'].str.contains('SUNBIT!'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('Alignment'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('tire'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('tires'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('TIRE'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('Tire'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('Stay Safe Now!'), 'Offer_Group'] = 'Key Products - Tires'
clean_data.loc[clean_data['Offer Text'].str.contains('STAY SAFE NOW'), 'Offer_Group'] = 'Key Products - Tires'

clean_data.loc[clean_data['Offer Text'].str.contains('Spend More, Save More'), 'Offer_Group'] = 'Spend More, Save More Special'

# Replace null values in a specific column, e.g., 'Column_Name'
clean_data['Offer_Group'].fillna("Other", inplace=True)


null_rows = clean_data[clean_data['Offer_Group'].isnull()]
unique_names = null_rows['Offer Text']
number_of_rows = unique_names.shape[0]

# !pip install xlsxwriter

writer = pd.ExcelWriter('final_clean_data_jan_mar23.xlsx', engine='xlsxwriter', options={'strings_to_urls': False})
clean_data.to_excel(writer, index=False, sheet_name='Sheet1', encoding='utf-8')
writer.save()

from google.colab import files
files.download('final_clean_data_jan_mar23.xlsx')

# %%
from google.colab import files
uploaded = files.upload()
import io

df = pd.read_csv(io.BytesIO(uploaded['bronze_offertext_offerreport.csv']))

# Replacing spaces with underscores in column names
df.columns = df.columns.str.replace(' ', '_')

# Process Offer_Text column:
# 1. Replace "&amp;" with "&"
# 2. Replace "\u2005" with a space
# 3. Remove characters except numbers, letters, $, and %
# 4. Convert to lowercase
# 5. Convert to lowercase
df['offers_text_standardized'] = df['Offer_Text'].str.replace("&amp;", "&")\
    .str.replace("\u2005", " ")\
    .str.replace(r'[^A-Za-z0-9$%]', '', regex=True)\
    .str.replace(" ", "")\
    .str.lower()

# Assign a unique ID to each unique value in the "offers_text_standardized" column
df['offer_id'] = df['offers_text_standardized'].factorize()[0] + 1

# Define a dictionary for string-category mapping
CATEGORY_MAP = {
    'oil': 'Oil',
    'accessories': 'Accessories',
    'accessory': 'Accessories',
    'orget': 'Combination Offer',
    'save$': 'Combination Offer',
    'milesservice': 'Service Discount',
    'nextservice': 'Service Discount',
    'anyservice': 'Service Discount',
    'offlabor': 'Service Discount',
    'toyotaseeaserviceassociate': 'Service Discount',
    'complimentarymaintenance': 'Service Discount',
    'recommendedservice': 'Service Discount',
    'offservice': 'Service Discount',
    'service': 'Service Discount',
    'tire': 'Tires',
    'wheelalignment': 'Tires',
    'battery': 'Batteries',
    'wiper': 'Wipers',
    'sunbit': 'Financing Offer',
    'filter': 'Filters',
    'brake': 'Brakes',
    '4th': 'Tires',
    # Add as many categories as needed
}

def categorize(value):
    # Ensure that the value is a string; if not, return 'other_category'
    if not isinstance(value, str):
        return 'other_category'

    for keyword, category in CATEGORY_MAP.items():
        if keyword in value:
            return category
    return 'other_category'

# Apply the function to create a new 'category' column in the dataframe
df['category'] = df['offers_text_standardized'].apply(categorize)

# Save the DataFrame to a CSV file
csv_filename = "silver_offertext_offerreport.csv"
df.to_csv(csv_filename, index=False)

# Offer the CSV file as a downloadable link
files.download(csv_filename)
